# %% [markdown]
# # Algoritmo Genético e Memetico
# Este notebook faz parte do projeto de grafos: [Garfos 3](https://)

# %% [markdown]
# A seguir o link para o próximoNotebook, sendo ele do [Algoritmo Memetico](https://)
